# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns 
plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv(r"C:\Users\itsno\Desktop\Portfolio Projects\portfolio_project_19_v1_pandas_analysis_python\csv_data\Life_Expectancy_Data.csv")

# %%
df.shape
# Out:
# (2938, 21)

# %%
df.head(5)
# Out:
#    Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0  2015  Developing              65.0            263.0             62
# 1  2014  Developing              59.9            271.0             64
# 2  2013  Developing              59.9            268.0             66
# 3  2012  Developing              59.5            272.0             69
# 4  2011  Developing              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# 0     0.01               71.279624         65.0      1154   19.1
# 1     0.01               73.523582         62.0       492   18.6
# 2     0.01               73.219243         64.0       430   18.1
# 3     0.01               78.184215         67.0      2787   17.6
# 4     0.01                7.097109         68.0      3013   17.2
#
#    under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0                  83    6.0               8.16         65.0        0.1
# ...

# %%
df.tail(5)
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 2933  2004  Developing              44.3            723.0             27
# 2934  2003  Developing              44.5            715.0             26
# 2935  2002  Developing              44.8             73.0             25
# 2936  2001  Developing              45.3            686.0             25
# 2937  2000  Developing              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# 2933     4.36                     0.0         68.0        31   27.1
# 2934     4.06                     0.0          7.0       998   26.7
# 2935     4.43                     0.0         73.0       304   26.3
# 2936     1.72                     0.0         76.0       529   25.9
# 2937     1.68                     0.0         79.0      1483   25.5
#
#       under-five deaths   Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             2938 non-null   int64
#  1   Status                           2938 non-null   object
#  2   Life expectancy                  2928 non-null   float64
#  3   Adult Mortality                  2928 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2744 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
# ...

# %%
df['GDP'].min()
# Out:
# 1.68135

# %%
df['GDP'].max()
# Out:
# 119172.7418

# %%
df['GDP'].mean()
# Out:
# 7483.158469138474

# %%
df.isnull()
# Out:
#        Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     False   False             False            False          False
# 1     False   False             False            False          False
# 2     False   False             False            False          False
# 3     False   False             False            False          False
# 4     False   False             False            False          False
# ...     ...     ...               ...              ...            ...
# 2933  False   False             False            False          False
# 2934  False   False             False            False          False
# 2935  False   False             False            False          False
# 2936  False   False             False            False          False
# 2937  False   False             False            False          False
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %%
df.isnull().sum()
# Out:
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
df.dropna(how = 'any', inplace = True) 
df
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     2015  Developing              65.0            263.0             62
# 1     2014  Developing              59.9            271.0             64
# 2     2013  Developing              59.9            268.0             66
# 3     2012  Developing              59.5            272.0             69
# 4     2011  Developing              59.2            275.0             71
# ...    ...         ...               ...              ...            ...
# 2933  2004  Developing              44.3            723.0             27
# 2934  2003  Developing              44.5            715.0             26
# 2935  2002  Developing              44.8             73.0             25
# 2936  2001  Developing              45.3            686.0             25
# 2937  2000  Developing              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %%
df.isnull().sum()
# Out:
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df = pd.read_csv(r"C:\Users\itsno\Desktop\Portfolio Projects\portfolio_project_19_v1_pandas_analysis_python\csv_data\Life_Expectancy_Data.csv")

# %%
df['GDP'].mean()

df['GDP'].fillna(df['GDP'].mean(), inplace = True)

# %%
df
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     2015  Developing              65.0            263.0             62
# 1     2014  Developing              59.9            271.0             64
# 2     2013  Developing              59.9            268.0             66
# 3     2012  Developing              59.5            272.0             69
# 4     2011  Developing              59.2            275.0             71
# ...    ...         ...               ...              ...            ...
# 2933  2004  Developing              44.3            723.0             27
# 2934  2003  Developing              44.5            715.0             26
# 2935  2002  Developing              44.8             73.0             25
# 2936  2001  Developing              45.3            686.0             25
# 2937  2000  Developing              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# ...

# %%
df['Total expenditure'].fillna(df['GDP'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                    0
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                  0
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df['Status']
# Out:
# 0       Developing
# 1       Developing
# 2       Developing
# 3       Developing
# 4       Developing
#            ...
# 2933    Developing
# 2934    Developing
# 2935    Developing
# 2936    Developing
# 2937    Developing
# Name: Status, Length: 2938, dtype: object

# %%
Status_Encoded = pd.get_dummies(df['Status'])
print(Status_Encoded)
# Out:
#       Developed  Developing
# 0             0           1
# 1             0           1
# 2             0           1
# 3             0           1
# 4             0           1
# ...         ...         ...
# 2933          0           1
# 2934          0           1
# 2935          0           1
# 2936          0           1
# 2937          0           1
#
# [2938 rows x 2 columns]

# %%
df.rename(columns={'Life expectancy ':'Life expectancy'}, inplace=True)

# %%
df['Life expectancy'].values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
#Normalizing the Life Expectancy data 

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Life expectancy'] = scaler.fit_transform(df['Life expectancy'].values.reshape(-1,1))

# %%
df['Life expectancy']
# Out:
# 0       0.544592
# 1       0.447818
# 2       0.447818
# 3       0.440228
# 4       0.434535
#           ...
# 2933    0.151803
# 2934    0.155598
# 2935    0.161290
# 2936    0.170778
# 2937    0.184061
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
#Sanity check 

round(df['Life expectancy'].describe())
# Out:
# count    2928.0
# mean        1.0
# std         0.0
# min         0.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: Life expectancy, dtype: float64

# %%
# Standardizing the Life Expectancy data

df = pd.read_csv(r"C:\Users\itsno\Desktop\Portfolio Projects\portfolio_project_19_v1_pandas_analysis_python\csv_data\Life_Expectancy_Data.csv")

# %%
df['Life expectancy '].values
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Life expectancy '] = scaler.fit_transform(df['Life expectancy '].values.reshape(-1,1))

# %%
df['Life expectancy ']
# Out:
# 0      -0.443691
# 1      -0.979279
# 2      -0.979279
# 3      -1.021286
# 4      -1.052791
#           ...
# 2933   -2.617549
# 2934   -2.596545
# 2935   -2.565040
# 2936   -2.512532
# 2937   -2.439020
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
# We have been informed that the percentage expenditure has increased by 5

# We define a function that increases all elements by a fixed value of 5% 

def percentage_expenditure_update(balance):
    return balance + 5

# %%
df['percentage expenditure'] = df['percentage expenditure'].apply(percentage_expenditure_update)

# %%
df
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     2015  Developing         -0.443691            263.0             62
# 1     2014  Developing         -0.979279            271.0             64
# 2     2013  Developing         -0.979279            268.0             66
# 3     2012  Developing         -1.021286            272.0             69
# 4     2011  Developing         -1.052791            275.0             71
# ...    ...         ...               ...              ...            ...
# 2933  2004  Developing         -2.617549            723.0             27
# 2934  2003  Developing         -2.596545            715.0             26
# 2935  2002  Developing         -2.565040             73.0             25
# 2936  2001  Developing         -2.512532            686.0             25
# 2937  2000  Developing         -2.439020            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# ...
